# %% [markdown]
# ## Libraries

# %%
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.svm import SVC
from reglog import LogisticRegression
from visualizer import plot_decision_boundary_with_metrics as visualize

# %% [markdown]
# ## General Setup

# %%
rs = 52 # i etot gorod nash

# %% [markdown]
# ## 1. Data Generation

# %%
X, y = make_moons(n_samples=10000, noise=0.25, random_state=rs)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=rs)

# %% [markdown]
# ## 2. Logistic Regression

# %%
logreg = LogisticRegression(random_state=rs)
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=52)

# %% [markdown]
# ## 3. Decision Tree

# %% [markdown]
# ### 3.1 Entropy _(+ `max_depth=1`)_

# %%
tree = DecisionTreeClassifier(criterion="entropy", random_state=rs, max_depth=1)
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=1, random_state=52)

# %% [markdown]
# ### 3.2 Gini

# %%
tree = DecisionTreeClassifier(criterion="gini", random_state=rs)
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=52)

# %% [markdown]
# ## 4. Random Forest

# %% [markdown]
# ### 4.1 10 Estimators

# %%
forest = RandomForestClassifier(n_estimators=10, random_state=rs, max_depth=4)
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=4, n_estimators=10, random_state=52)

# %% [markdown]
# ### 4.2 50 Estimators

# %%
forest = RandomForestClassifier(n_estimators=50, random_state=rs, max_depth=4)
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=4, n_estimators=50, random_state=52)

# %% [markdown]
# ### 4.3 100 Estimators

# %%
forest = RandomForestClassifier(n_estimators=100, random_state=rs, max_depth=4)
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=4, random_state=52)

# %% [markdown]
# ## 5. SVM

# %%
svc = SVC(probability=True, random_state=rs)
svc.fit(X_train, y_train)
# Out:
# SVC(probability=True, random_state=52)

# %% [markdown]
# ## 6. Ensemble

# %%
estimators = [("logreg", logreg), ("tree", tree), ("forest", forest), ("svc", svc)]
ensemble = VotingClassifier(estimators=estimators, voting="soft")
ensemble.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('logreg', LogisticRegression(random_state=52)),
#                              ('tree', DecisionTreeClassifier(random_state=52)),
#                              ('forest',
#                               RandomForestClassifier(max_depth=4,
#                                                      random_state=52)),
#                              ('svc', SVC(probability=True, random_state=52))],
#                  voting='soft')

# %% [markdown]
# ## 7 Evaluation

# %%
visualize(logreg, X_train, y_train, X_test, y_test, title="Logistic Regression", show_precision=True)
visualize(tree, X_train, y_train, X_test, y_test, title="Decision Tree", show_precision=True)
visualize(forest, X_train, y_train, X_test, y_test, title="Random Forest", show_precision=True)
visualize(svc, X_train, y_train, X_test, y_test, title="SVM", show_precision=True)
visualize(ensemble, X_train, y_train, X_test, y_test, title="Ensemble", show_precision=True)
